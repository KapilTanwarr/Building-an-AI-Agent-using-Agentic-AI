# %% [markdown]
# # Understanding the Components of Agentic AI
# Agentic AI involves several key components. In this article, I’ll be building an AI Agent for trading. So, let’s understand the key components of Agentic AI with our example:
#
# ### 1. The Agent:
# The agent is the decision-making entity in the AI system. In our case, the DQN trading agent will be responsible for making trading decisions based on market data.
# ### 2. The Environment:
# The environment is the external system in which the agent operates. Our trading environment will consist of stock market data, where the agent will interact with price movements and execute trades.
# ### 3. The State:
# The state represents the information available to the agent at any given time. Our trading agent’s state includes the stock’s closing price, moving averages, and daily returns.
# ### 4. The Action Space:
# The action space defines what actions the agent can take. Our trading agent has three possible actions: Buy, Sell, and Hold.
# ### 5. The Reward Function:
# The reward function determines the agent’s performance by assigning a numerical value to its actions. The goal of our trading agent will be to maximize total profit by the end of the trading session.
#
# Having this knowledge will help you understand all the steps we will take further to build an AI Agent using Agentic AI.

# %% [markdown]
# ## Building an AI Agent using Agentic AI: Getting Started
# Now, let’s get started with building an AI Agent for trading using Agentic AI. I’ll first import all the necessary Python libraries and collect Apple’s stock market data from Yahoo Finance:

# %%
import yfinance as yf
import pandas as pd
import numpy as np
import torch
import torch.nn as nn
import torch.optim as optim
import random
from collections import deque

# define stock symbol and time period
symbol = "AAPL"
start_date = "2020-01-01"
end_date = "2025-02-14"

# download historical data
data = yf.download(symbol, start=start_date, end=end_date)
# Out:
# /tmp/ipython-input-1-2026925277.py:16: FutureWarning: YF.download() has changed argument auto_adjust default to True
#   data = yf.download(symbol, start=start_date, end=end_date)
# [*********************100%***********************]  1 of 1 completed

# %% [markdown]
# Now, we will calculate technical indicators that help the AI agent make better trading decisions:

# %%
# feature engineering
data['SMA_5'] = data['Close'].rolling(window=5).mean()
data['SMA_20'] = data['Close'].rolling(window=20).mean()
data['Returns'] = data['Close'].pct_change()

# %% [markdown]
# Now, let’s drop missing values and reset the index:

# %%
# drop NaN values and reset index
data.dropna(inplace=True)
data.reset_index(drop=True, inplace=True)

# %% [markdown]
# Next, we will define the action space. The AI agent has three possible actions:
#
# HOLD: Do nothing.
#
# BUY: Purchase stocks.
#
# SELL: Sell held stocks.

# %%
# define action space
ACTIONS = {0: "HOLD", 1: "BUY", 2: "SELL"}

# %% [markdown]
# This action space is used to train the reinforcement learning model.
#
# Now, we will extract the State from the data:

# %%
# get state function
def get_state(data, index):
    return np.array([
        float(data.loc[index, 'Close']),
        float(data.loc[index, 'SMA_5']),
        float(data.loc[index, 'SMA_20']),
        float(data.loc[index, 'Returns'])
    ])

# %% [markdown]
# This function extracts the state representation from the dataset at a given time index. The state is an array containing:
#
# - Closing price
#
# - 5-day SMA
#
# - 20-day SMA
#
# - Daily return percentage
#
# This numerical representation of the stock market is fed into the AI model to make trading decisions.

# %% [markdown]
# ## Building The Trading Environment for our AI Agent
# We will now define a trading environment to interact with the Deep Q-Network (DQN) AI agent, which will allow it to learn how to trade stocks profitably:

# %%
# trading environment
class TradingEnvironment:
    def __init__(self, data):
        self.data = data
        self.initial_balance = 10000
        self.balance = self.initial_balance
        self.holdings = 0
        self.index = 0

    def reset(self):
        self.balance = self.initial_balance
        self.holdings = 0
        self.index = 0
        return get_state(self.data, self.index)

    def step(self, action):
        price = float(self.data.loc[self.index, 'Close'])
        reward = 0

        if action == 1 and self.balance >= price:  # BUY
            self.holdings = self.balance // price
            self.balance -= self.holdings * price
        elif action == 2 and self.holdings > 0:  # SELL
            self.balance += self.holdings * price
            self.holdings = 0

        self.index += 1
        done = self.index >= len(self.data) - 1

        if done:
            reward = self.balance - self.initial_balance

        next_state = get_state(self.data, self.index) if not done else None
        return next_state, reward, done, {}

# %% [markdown]
# The environment is implemented as a class that simulates the stock market. It tracks the agent’s balance, holdings, and current market index, and it provides new states and rewards in response to the agent’s actions.

# %% [markdown]
# ## The Deep Q-Network (DQN)
# DQN is a neural network that approximates the Q-values for each state-action pair. We will now define the neural network architecture for our Deep Q-Network. It will be responsible for predicting the best trading actions based on the stock market state:

# %%
# deep q-network
class DQN(nn.Module):
    def __init__(self, state_size, action_size):
        super(DQN, self).__init__()
        self.fc1 = nn.Linear(state_size, 64)
        self.fc2 = nn.Linear(64, 64)
        self.fc3 = nn.Linear(64, action_size)

    def forward(self, x):
        x = torch.relu(self.fc1(x))
        x = torch.relu(self.fc2(x))
        return self.fc3(x)

# %% [markdown]
# Here we built a Deep Q-Network using PyTorch to optimize stock trading decisions. The model features a three-layer neural network to predict trading actions, leveraging ReLU activation to enhance learning efficiency.
#
#
# It outputs Q-values, which the agent utilizes to determine the best action: buy, sell, or hold, based on market conditions.

# %% [markdown]
# ## The DQN Agent
# Now, we will implement the AI agent that learns how to trade stocks using Deep Q-Learning. The DQN Agent will interact with the trading environment, make trading decisions (BUY, SELL, HOLD), store experiences, and learn from past experiences to improve future decisions:

# %%
# DQN agent
class DQNAgent:
    def __init__(self, state_size, action_size):
        self.state_size = state_size
        self.action_size = action_size
        self.memory = deque(maxlen=2000)
        self.gamma = 0.95  # Discount factor
        self.epsilon = 1.0  # Exploration rate
        self.epsilon_min = 0.01
        self.epsilon_decay = 0.995
        self.learning_rate = 0.001
        self.model = DQN(state_size, action_size)
        self.optimizer = optim.Adam(self.model.parameters(), lr=self.learning_rate)
        self.criterion = nn.MSELoss()

    def remember(self, state, action, reward, next_state, done):
        self.memory.append((state, action, reward, next_state, done))

    def act(self, state):
        if random.uniform(0, 1) < self.epsilon:
            return random.choice(list(ACTIONS.keys()))
        state = torch.FloatTensor(state).unsqueeze(0)
        with torch.no_grad():
            q_values = self.model(state)
        return torch.argmax(q_values).item()

    def replay(self, batch_size):
        if len(self.memory) < batch_size:
            return
        minibatch = random.sample(self.memory, batch_size)

        for state, action, reward, next_state, done in minibatch:
            target = reward
            if not done:
                next_state_tensor = torch.FloatTensor(next_state).unsqueeze(0)
                target += self.gamma * torch.max(self.model(next_state_tensor)).item()

            state_tensor = torch.FloatTensor(state).unsqueeze(0)
            target_tensor = self.model(state_tensor).clone().detach()
            target_tensor[0][action] = target

            self.optimizer.zero_grad()
            output = self.model(state_tensor)
            loss = self.criterion(output, target_tensor)
            loss.backward()
            self.optimizer.step()

        if self.epsilon > self.epsilon_min:
            self.epsilon *= self.epsilon_decay

# %% [markdown]
# So, we developed a Deep Q-Learning Agent to interact with the stock market environment to enhance its decision-making through Experience Replay, which stores and reuses past experiences for training. The agent effectively balances Exploration vs. Exploitation, taking random actions initially and making smarter decisions as learning progresses.
#
# Training is performed using batches of past experiences to refine the neural network’s performance. Additionally, a discount factor (gamma) is applied to weigh immediate and future rewards, to ensure long-term profitability.

# %% [markdown]
# ## Training the AI Agent
# Training involves running multiple episodes where the agent interacts with the environment, learns from experience, and updates its model. Let’s train the agent:

# %%
# train the agent
env = TradingEnvironment(data)
agent = DQNAgent(state_size=4, action_size=3)
batch_size = 32
episodes = 500
total_rewards = []

for episode in range(episodes):
    state = env.reset()
    done = False
    total_reward = 0

    while not done:
        action = agent.act(state)
        next_state, reward, done, _ = env.step(action)
        agent.remember(state, action, reward, next_state, done)
        state = next_state
        total_reward += reward

    agent.replay(batch_size)
    total_rewards.append(total_reward)
    print(f"Episode {episode+1}/{episodes}, Total Reward: {total_reward}")

print("Training Complete!")
# Out:
# /tmp/ipython-input-5-3109401411.py:4: FutureWarning: Calling float on a single element Series is deprecated and will raise a TypeError in the future. Use float(ser.iloc[0]) instead
#   float(data.loc[index, 'Close']),
# /tmp/ipython-input-5-3109401411.py:5: FutureWarning: Calling float on a single element Series is deprecated and will raise a TypeError in the future. Use float(ser.iloc[0]) instead
#   float(data.loc[index, 'SMA_5']),
# /tmp/ipython-input-5-3109401411.py:6: FutureWarning: Calling float on a single element Series is deprecated and will raise a TypeError in the future. Use float(ser.iloc[0]) instead
#   float(data.loc[index, 'SMA_20']),
# /tmp/ipython-input-5-3109401411.py:7: FutureWarning: Calling float on a single element Series is deprecated and will raise a TypeError in the future. Use float(ser.iloc[0]) instead
#   float(data.loc[index, 'Returns'])
# /tmp/ipython-input-6-2218621516.py:17: FutureWarning: Calling float on a single element Series is deprecated and will raise a TypeError in the future. Use float(ser.iloc[0]) instead
#   price = float(self.data.loc[self.index, 'Close'])
# Episode 1/500, Total Reward: -9832.96403503418
# Episode 2/500, Total Reward: -9895.818672180176
# Episode 3/500, Total Reward: -9941.44945526123
# Episode 4/500, Total Reward: 21250.57292175293
# Episode 5/500, Total Reward: -9985.075832366943
# Episode 6/500, Total Reward: -9939.087169647217
# Episode 7/500, Total Reward: -9802.682891845703
# Episode 8/500, Total Reward: -9833.240798950195
# Episode 9/500, Total Reward: -9929.55477142334
# Episode 10/500, Total Reward: -9791.686000823975
# Episode 11/500, Total Reward: 8521.327041625977
# Episode 12/500, Total Reward: -9833.057037353516
# Episode 13/500, Total Reward: -9851.15193939209
# Episode 14/500, Total Reward: -9840.269008636475
# Episode 15/500, Total Reward: -9881.922039031982
# Episode 16/500, Total Reward: -9926.612964630127
# Episode 17/500, Total Reward: -9928.098426818848
# Episode 18/500, Total Reward: -9824.735893249512
# Episode 19/500, Total Reward: -9909.33479309082
# Episode 20/500, Total Reward: -9890.009296417236
# Episode 21/500, Total Reward: -9864.591293334961
# Episode 22/500, Total Reward: -9860.698802947998
# Episode 23/500, Total Reward: -9939.211208343506
# Episode 24/500, Total Reward: -9859.347961425781
# Episode 25/500, Total Reward: -9858.208702087402
# Episode 26/500, Total Reward: -9930.855415344238
# Episode 27/500, Total Reward: -9817.331367492676
# Episode 28/500, Total Reward: -9875.966537475586
# Episode 29/500, Total Reward: 335.5500717163086
# Episode 30/500, Total Reward: -9777.235782623291
# Episode 31/500, Total Reward: 9887.520713806152
# Episode 32/500, Total Reward: -9931.737319946289
# Episode 33/500, Total Reward: -9875.935665130615
# Episode 34/500, Total Reward: -9766.670627593994
# Episode 35/500, Total Reward: -9995.4052734375
# Episode 36/500, Total Reward: -9884.699653625488
# Episode 37/500, Total Reward: -9832.459537506104
# Episode 38/500, Total Reward: -9870.553073883057
# Episode 39/500, Total Reward: -9885.162929534912
# Episode 40/500, Total Reward: -9979.125785827637
# Episode 41/500, Total Reward: -9932.306240081787
# Episode 42/500, Total Reward: -9827.292427062988
# Episode 43/500, Total Reward: -9872.198318481445
# Episode 44/500, Total Reward: -9865.723808288574
# Episode 45/500, Total Reward: -9771.493488311768
# Episode 46/500, Total Reward: 3268.992820739746
# Episode 47/500, Total Reward: -9940.204067230225
# Episode 48/500, Total Reward: -9988.4361038208
# Episode 49/500, Total Reward: -9837.423011779785
# Episode 50/500, Total Reward: -9858.43330001831
# Episode 51/500, Total Reward: -9832.979873657227
# Episode 52/500, Total Reward: -9961.858070373535
# Episode 53/500, Total Reward: 4468.73051071167
# Episode 54/500, Total Reward: -9888.569194793701
# Episode 55/500, Total Reward: -9802.819061279297
# Episode 56/500, Total Reward: -9891.94915008545
# Episode 57/500, Total Reward: -9910.906044006348
# Episode 58/500, Total Reward: -9853.49264907837
# Episode 59/500, Total Reward: -9885.71300125122
# Episode 60/500, Total Reward: -9996.665405273438
# Episode 61/500, Total Reward: -9820.785301208496
# Episode 62/500, Total Reward: -9784.294666290283
# Episode 63/500, Total Reward: -9868.358451843262
# Episode 64/500, Total Reward: -9788.298843383789
# Episode 65/500, Total Reward: -9868.386325836182
# Episode 66/500, Total Reward: -9844.459411621094
# Episode 67/500, Total Reward: -9810.833950042725
# Episode 68/500, Total Reward: -9835.61113357544
# Episode 69/500, Total Reward: -9807.55661392212
# Episode 70/500, Total Reward: -9869.795249938965
# Episode 71/500, Total Reward: -9993.408130645752
# Episode 72/500, Total Reward: -9927.036235809326
# Episode 73/500, Total Reward: -9800.294536590576
# Episode 74/500, Total Reward: -9832.248970031738
# Episode 75/500, Total Reward: -9941.667560577393
# Episode 76/500, Total Reward: -9856.894470214844
# Episode 77/500, Total Reward: -9862.044555664062
# Episode 78/500, Total Reward: 5973.530811309814
# Episode 79/500, Total Reward: -9877.03384399414
# Episode 80/500, Total Reward: 5726.587455749512
# Episode 81/500, Total Reward: -9874.514419555664
# Episode 82/500, Total Reward: 3852.0187606811523
# Episode 83/500, Total Reward: -9745.237628936768
# Episode 84/500, Total Reward: -9776.351062774658
# Episode 85/500, Total Reward: -9778.583889007568
# Episode 86/500, Total Reward: -9767.086093902588
# Episode 87/500, Total Reward: -9936.369853973389
# Episode 88/500, Total Reward: -9939.414161682129
# Episode 89/500, Total Reward: -9846.933311462402
# Episode 90/500, Total Reward: -9854.620944976807
# Episode 91/500, Total Reward: -9866.38589477539
# Episode 92/500, Total Reward: 3296.9400787353516
# Episode 93/500, Total Reward: 2362.5487747192383
# Episode 94/500, Total Reward: 7252.732330322266
# Episode 95/500, Total Reward: -9936.212978363037
# Episode 96/500, Total Reward: -9849.689529418945
# Episode 97/500, Total Reward: -9919.720077514648
# Episode 98/500, Total Reward: -9884.193382263184
# Episode 99/500, Total Reward: -9891.318462371826
# Episode 100/500, Total Reward: -9875.913578033447
# Episode 101/500, Total Reward: -9779.529998779297
# Episode 102/500, Total Reward: 5686.756790161133
# Episode 103/500, Total Reward: -385.5088233947754
# Episode 104/500, Total Reward: -9912.0433883667
# Episode 105/500, Total Reward: 5137.566623687744
# Episode 106/500, Total Reward: -9860.697715759277
# Episode 107/500, Total Reward: 5724.914318084717
# Episode 108/500, Total Reward: 16824.882034301758
# Episode 109/500, Total Reward: -9843.768611907959
# Episode 110/500, Total Reward: -9760.021472930908
# Episode 111/500, Total Reward: -491.2913627624512
# Episode 112/500, Total Reward: -9749.633056640625
# Episode 113/500, Total Reward: -9926.999351501465
# Episode 114/500, Total Reward: 7580.330661773682
# Episode 115/500, Total Reward: -9848.253074645996
# Episode 116/500, Total Reward: -9769.145980834961
# Episode 117/500, Total Reward: -9866.616020202637
# Episode 118/500, Total Reward: 4816.591033935547
# Episode 119/500, Total Reward: -9836.24641418457
# Episode 120/500, Total Reward: -9769.563621520996
# Episode 121/500, Total Reward: -9855.203643798828
# Episode 122/500, Total Reward: 9016.76891708374
# Episode 123/500, Total Reward: -9829.100933074951
# Episode 124/500, Total Reward: -9881.666706085205
# Episode 125/500, Total Reward: -9791.027786254883
# Episode 126/500, Total Reward: -9759.421745300293
# Episode 127/500, Total Reward: 3402.1412773132324
# Episode 128/500, Total Reward: -9877.04135131836
# Episode 129/500, Total Reward: -9830.589881896973
# Episode 130/500, Total Reward: -9983.666591644287
# Episode 131/500, Total Reward: -9889.576732635498
# Episode 132/500, Total Reward: -9776.321514129639
# Episode 133/500, Total Reward: 7957.60249710083
# Episode 134/500, Total Reward: -9844.960830688477
# Episode 135/500, Total Reward: -9939.509712219238
# Episode 136/500, Total Reward: -9887.60717010498
# Episode 137/500, Total Reward: -9734.746002197266
# Episode 138/500, Total Reward: -9846.601207733154
# Episode 139/500, Total Reward: -9819.488079071045
# Episode 140/500, Total Reward: -9933.031745910645
# Episode 141/500, Total Reward: -9809.968021392822
# Episode 142/500, Total Reward: 2930.1447525024414
# Episode 143/500, Total Reward: -9784.480865478516
# Episode 144/500, Total Reward: -9832.552143096924
# Episode 145/500, Total Reward: -9856.713172912598
# Episode 146/500, Total Reward: -9786.360610961914
# Episode 147/500, Total Reward: -9831.774269104004
# Episode 148/500, Total Reward: 30443.425987243652
# Episode 149/500, Total Reward: -9799.61294555664
# Episode 150/500, Total Reward: -9783.545070648193
# Episode 151/500, Total Reward: -9876.431617736816
# Episode 152/500, Total Reward: -9781.296585083008
# Episode 153/500, Total Reward: 13628.172821044922
# Episode 154/500, Total Reward: -9776.821613311768
# Episode 155/500, Total Reward: -9741.687126159668
# Episode 156/500, Total Reward: 1270.6051406860352
# Episode 157/500, Total Reward: -9754.729598999023
# Episode 158/500, Total Reward: -1260.075382232666
# Episode 159/500, Total Reward: -9813.245834350586
# Episode 160/500, Total Reward: -2454.03897857666
# Episode 161/500, Total Reward: -9917.720672607422
# Episode 162/500, Total Reward: -9826.006942749023
# Episode 163/500, Total Reward: -9931.160736083984
# Episode 164/500, Total Reward: -9933.900539398193
# Episode 165/500, Total Reward: -9863.257816314697
# Episode 166/500, Total Reward: 2221.3755493164062
# Episode 167/500, Total Reward: 175.68842315673828
# Episode 168/500, Total Reward: 3545.5306129455566
# Episode 169/500, Total Reward: -9937.480640411377
# Episode 170/500, Total Reward: -1931.8100204467773
# Episode 171/500, Total Reward: -9794.931255340576
# Episode 172/500, Total Reward: -9970.575214385986
# Episode 173/500, Total Reward: -9833.252052307129
# Episode 174/500, Total Reward: -9925.117561340332
# Episode 175/500, Total Reward: -9757.246826171875
# Episode 176/500, Total Reward: 7635.245094299316
# Episode 177/500, Total Reward: 5401.847702026367
# Episode 178/500, Total Reward: -9818.030658721924
# Episode 179/500, Total Reward: 3078.2524070739746
# Episode 180/500, Total Reward: -9767.296100616455
# Episode 181/500, Total Reward: 9160.684280395508
# Episode 182/500, Total Reward: -9870.91794204712
# Episode 183/500, Total Reward: -9980.206321716309
# Episode 184/500, Total Reward: -9871.610076904297
# Episode 185/500, Total Reward: -9782.054565429688
# Episode 186/500, Total Reward: -9883.645881652832
# Episode 187/500, Total Reward: -9987.710357666016
# Episode 188/500, Total Reward: -1278.8809280395508
# Episode 189/500, Total Reward: -9922.850212097168
# Episode 190/500, Total Reward: -9961.769374847412
# Episode 191/500, Total Reward: -9845.121368408203
# Episode 192/500, Total Reward: -9811.209365844727
# Episode 193/500, Total Reward: -9905.192882537842
# Episode 194/500, Total Reward: -9930.920406341553
# Episode 195/500, Total Reward: -9927.199085235596
# Episode 196/500, Total Reward: 7886.598217010498
# Episode 197/500, Total Reward: -9920.676517486572
# Episode 198/500, Total Reward: 13302.593788146973
# Episode 199/500, Total Reward: -9856.647899627686
# Episode 200/500, Total Reward: -9861.15019607544
# Episode 201/500, Total Reward: -9824.963523864746
# Episode 202/500, Total Reward: 9184.374015808105
# Episode 203/500, Total Reward: -9814.83129119873
# Episode 204/500, Total Reward: -9911.764793395996
# Episode 205/500, Total Reward: -9875.28702545166
# Episode 206/500, Total Reward: -9983.171932220459
# Episode 207/500, Total Reward: -9844.661277770996
# Episode 208/500, Total Reward: -9981.982479095459
# Episode 209/500, Total Reward: -9910.460788726807
# Episode 210/500, Total Reward: -9818.709274291992
# Episode 211/500, Total Reward: -9976.95288848877
# Episode 212/500, Total Reward: -9877.680671691895
# Episode 213/500, Total Reward: -9797.814002990723
# Episode 214/500, Total Reward: 6971.486549377441
# Episode 215/500, Total Reward: 6801.692790985107
# Episode 216/500, Total Reward: 5700.812858581543
# Episode 217/500, Total Reward: -9779.961921691895
# Episode 218/500, Total Reward: -9811.616401672363
# Episode 219/500, Total Reward: 7726.424530029297
# Episode 220/500, Total Reward: 5012.381198883057
# Episode 221/500, Total Reward: -9751.474029541016
# Episode 222/500, Total Reward: -9940.654991149902
# Episode 223/500, Total Reward: -9999.878017425537
# Episode 224/500, Total Reward: -9786.444244384766
# Episode 225/500, Total Reward: -9848.321044921875
# Episode 226/500, Total Reward: 10456.999851226807
# Episode 227/500, Total Reward: 12092.16439819336
# Episode 228/500, Total Reward: 6505.362186431885
# Episode 229/500, Total Reward: -9824.091022491455
# Episode 230/500, Total Reward: 8941.276878356934
# Episode 231/500, Total Reward: 8143.317596435547
# Episode 232/500, Total Reward: -9823.485458374023
# Episode 233/500, Total Reward: -9815.940376281738
# Episode 234/500, Total Reward: -9817.322967529297
# Episode 235/500, Total Reward: -9860.573760986328
# Episode 236/500, Total Reward: -1178.5243034362793
# Episode 237/500, Total Reward: -9974.66735458374
# Episode 238/500, Total Reward: -9749.344867706299
# Episode 239/500, Total Reward: -9976.6763381958
# Episode 240/500, Total Reward: -9784.741031646729
# Episode 241/500, Total Reward: -9894.571044921875
# Episode 242/500, Total Reward: -9877.335304260254
# Episode 243/500, Total Reward: -9817.178207397461
# Episode 244/500, Total Reward: 8549.674861907959
# Episode 245/500, Total Reward: -9918.545471191406
# Episode 246/500, Total Reward: -9994.635719299316
# Episode 247/500, Total Reward: 4687.537078857422
# Episode 248/500, Total Reward: -9927.612937927246
# Episode 249/500, Total Reward: -9838.126037597656
# Episode 250/500, Total Reward: -9840.9292678833
# Episode 251/500, Total Reward: -9824.858352661133
# Episode 252/500, Total Reward: -9994.176090240479
# Episode 253/500, Total Reward: -9775.347106933594
# Episode 254/500, Total Reward: -9925.589241027832
# Episode 255/500, Total Reward: -9935.842582702637
# Episode 256/500, Total Reward: -9847.22696685791
# Episode 257/500, Total Reward: -9990.928367614746
# Episode 258/500, Total Reward: -9837.190467834473
# Episode 259/500, Total Reward: -9832.91247177124
# Episode 260/500, Total Reward: -9775.447856903076
# Episode 261/500, Total Reward: -9941.207279205322
# Episode 262/500, Total Reward: -9921.381736755371
# Episode 263/500, Total Reward: -9893.343147277832
# Episode 264/500, Total Reward: -9785.291416168213
# Episode 265/500, Total Reward: -9756.17317199707
# Episode 266/500, Total Reward: -9825.173149108887
# Episode 267/500, Total Reward: -9817.945625305176
# Episode 268/500, Total Reward: -9761.034629821777
# Episode 269/500, Total Reward: 5619.588653564453
# Episode 270/500, Total Reward: -9935.439640045166
# Episode 271/500, Total Reward: -9837.001243591309
# Episode 272/500, Total Reward: -9803.353424072266
# Episode 273/500, Total Reward: -9863.559558868408
# Episode 274/500, Total Reward: -9888.510879516602
# Episode 275/500, Total Reward: -9905.470359802246
# Episode 276/500, Total Reward: -9833.94474029541
# Episode 277/500, Total Reward: 21376.306728363037
# Episode 278/500, Total Reward: -9793.307922363281
# Episode 279/500, Total Reward: -9797.454460144043
# Episode 280/500, Total Reward: -9783.495620727539
# Episode 281/500, Total Reward: -9876.543968200684
# Episode 282/500, Total Reward: -9984.780155181885
# Episode 283/500, Total Reward: -9815.717407226562
# Episode 284/500, Total Reward: -9919.195304870605
# Episode 285/500, Total Reward: -9806.56118774414
# Episode 286/500, Total Reward: -9907.143966674805
# Episode 287/500, Total Reward: -9791.597476959229
# Episode 288/500, Total Reward: -9794.189083099365
# Episode 289/500, Total Reward: -9843.343078613281
# Episode 290/500, Total Reward: -9813.301975250244
# Episode 291/500, Total Reward: -9864.326126098633
# Episode 292/500, Total Reward: 1662.9521255493164
# Episode 293/500, Total Reward: 11405.204559326172
# Episode 294/500, Total Reward: 25299.069087982178
# Episode 295/500, Total Reward: -9855.470561981201
# Episode 296/500, Total Reward: -9824.771472930908
# Episode 297/500, Total Reward: -9826.488327026367
# Episode 298/500, Total Reward: -9932.892795562744
# Episode 299/500, Total Reward: -9757.99515914917
# Episode 300/500, Total Reward: -9840.972213745117
# Episode 301/500, Total Reward: -9810.163787841797
# Episode 302/500, Total Reward: -9931.794555664062
# Episode 303/500, Total Reward: -9930.31922531128
# Episode 304/500, Total Reward: -9917.699813842773
# Episode 305/500, Total Reward: 13126.282466888428
# Episode 306/500, Total Reward: -9845.51734161377
# Episode 307/500, Total Reward: -9892.067180633545
# Episode 308/500, Total Reward: -9867.169132232666
# Episode 309/500, Total Reward: -9813.605323791504
# Episode 310/500, Total Reward: -9994.666316986084
# Episode 311/500, Total Reward: -9971.46028137207
# Episode 312/500, Total Reward: -9932.70654296875
# Episode 313/500, Total Reward: -9925.888610839844
# Episode 314/500, Total Reward: 5818.370349884033
# Episode 315/500, Total Reward: -9986.752674102783
# Episode 316/500, Total Reward: 17873.957721710205
# Episode 317/500, Total Reward: -9891.681968688965
# Episode 318/500, Total Reward: -9851.442928314209
# Episode 319/500, Total Reward: -9802.320262908936
# Episode 320/500, Total Reward: -9755.802791595459
# Episode 321/500, Total Reward: -9978.0016746521
# Episode 322/500, Total Reward: -9747.751689910889
# Episode 323/500, Total Reward: -9987.370429992676
# Episode 324/500, Total Reward: -9826.287155151367
# Episode 325/500, Total Reward: -139.0615119934082
# Episode 326/500, Total Reward: 2213.859718322754
# Episode 327/500, Total Reward: 2205.507942199707
# Episode 328/500, Total Reward: 2462.33797454834
# Episode 329/500, Total Reward: 335.0590133666992
# Episode 330/500, Total Reward: 2176.3613815307617
# Episode 331/500, Total Reward: -9929.480323791504
# Episode 332/500, Total Reward: 2046.656364440918
# Episode 333/500, Total Reward: -4.558387756347656
# Episode 334/500, Total Reward: 2446.2939376831055
# Episode 335/500, Total Reward: -586.1106948852539
# Episode 336/500, Total Reward: -531.9457931518555
# Episode 337/500, Total Reward: 375.27487564086914
# Episode 338/500, Total Reward: 1552.3756713867188
# Episode 339/500, Total Reward: -346.69789123535156
# Episode 340/500, Total Reward: 37.71739959716797
# Episode 341/500, Total Reward: -1017.407470703125
# Episode 342/500, Total Reward: -7.336585998535156
# Episode 343/500, Total Reward: 6455.10791015625
# Episode 344/500, Total Reward: 991.3951568603516
# Episode 345/500, Total Reward: 941.9897537231445
# Episode 346/500, Total Reward: 2217.906448364258
# Episode 347/500, Total Reward: 343.4833641052246
# Episode 348/500, Total Reward: 379.8561553955078
# Episode 349/500, Total Reward: 2052.2167053222656
# Episode 350/500, Total Reward: 1265.2744903564453
# Episode 351/500, Total Reward: 2689.240936279297
# Episode 352/500, Total Reward: -9857.342845916748
# Episode 353/500, Total Reward: 771.0815467834473
# Episode 354/500, Total Reward: 974.0777740478516
# Episode 355/500, Total Reward: 1420.4077606201172
# Episode 356/500, Total Reward: 3264.7524070739746
# Episode 357/500, Total Reward: 5209.855792999268
# Episode 358/500, Total Reward: -1808.7075881958008
# Episode 359/500, Total Reward: -240.1998748779297
# Episode 360/500, Total Reward: -2618.221508026123
# Episode 361/500, Total Reward: -918.3601379394531
# Episode 362/500, Total Reward: -9920.753005981445
# Episode 363/500, Total Reward: -192.98132705688477
# Episode 364/500, Total Reward: -1556.8842964172363
# Episode 365/500, Total Reward: 1567.4554824829102
# Episode 366/500, Total Reward: 1527.115951538086
# Episode 367/500, Total Reward: -2740.1881370544434
# Episode 368/500, Total Reward: 1342.8077812194824
# Episode 369/500, Total Reward: -1333.2751007080078
# Episode 370/500, Total Reward: 441.1539535522461
# Episode 371/500, Total Reward: 234.80284881591797
# Episode 372/500, Total Reward: 100.27483367919922
# Episode 373/500, Total Reward: -1557.2590408325195
# Episode 374/500, Total Reward: 29.43132781982422
# Episode 375/500, Total Reward: 1457.4694595336914
# Episode 376/500, Total Reward: 1394.1827697753906
# Episode 377/500, Total Reward: -473.5695037841797
# Episode 378/500, Total Reward: 920.2625579833984
# Episode 379/500, Total Reward: -267.716064453125
# Episode 380/500, Total Reward: -1594.3087921142578
# Episode 381/500, Total Reward: -576.400707244873
# Episode 382/500, Total Reward: 906.8595886230469
# Episode 383/500, Total Reward: -1473.2103881835938
# Episode 384/500, Total Reward: 2829.221710205078
# Episode 385/500, Total Reward: -922.1570816040039
# Episode 386/500, Total Reward: -186.41836547851562
# Episode 387/500, Total Reward: 3773.562587738037
# Episode 388/500, Total Reward: 1276.681526184082
# Episode 389/500, Total Reward: 1071.345558166504
# Episode 390/500, Total Reward: -9841.964469909668
# Episode 391/500, Total Reward: -63.2654914855957
# Episode 392/500, Total Reward: -2024.403953552246
# Episode 393/500, Total Reward: 3583.7920303344727
# Episode 394/500, Total Reward: 1203.1364059448242
# Episode 395/500, Total Reward: 1060.5242004394531
# Episode 396/500, Total Reward: -191.9543571472168
# Episode 397/500, Total Reward: 967.8955612182617
# Episode 398/500, Total Reward: 594.795295715332
# Episode 399/500, Total Reward: -9854.305145263672
# Episode 400/500, Total Reward: 1826.7747802734375
# Episode 401/500, Total Reward: 974.8722839355469
# Episode 402/500, Total Reward: -1876.1326141357422
# Episode 403/500, Total Reward: 598.2410659790039
# Episode 404/500, Total Reward: 441.6089096069336
# Episode 405/500, Total Reward: 1216.4918403625488
# Episode 406/500, Total Reward: 954.4577217102051
# Episode 407/500, Total Reward: -538.8440093994141
# Episode 408/500, Total Reward: 638.7378540039062
# Episode 409/500, Total Reward: 1041.5971069335938
# Episode 410/500, Total Reward: -3.2652053833007812
# Episode 411/500, Total Reward: 3026.090965270996
# Episode 412/500, Total Reward: 944.1025161743164
# Episode 413/500, Total Reward: 3276.204315185547
# Episode 414/500, Total Reward: -235.70563507080078
# Episode 415/500, Total Reward: -174.44231414794922
# Episode 416/500, Total Reward: 1900.7541198730469
# Episode 417/500, Total Reward: -9765.776313781738
# Episode 418/500, Total Reward: 351.15818786621094
# Episode 419/500, Total Reward: 537.2745056152344
# Episode 420/500, Total Reward: -785.8634452819824
# Episode 421/500, Total Reward: -154.52838897705078
# Episode 422/500, Total Reward: -593.9608993530273
# Episode 423/500, Total Reward: -103.9234390258789
# Episode 424/500, Total Reward: -539.4555511474609
# Episode 425/500, Total Reward: -83.49493026733398
# Episode 426/500, Total Reward: 1895.8197174072266
# Episode 427/500, Total Reward: -326.5517272949219
# Episode 428/500, Total Reward: 2535.2137184143066
# Episode 429/500, Total Reward: 1997.3559494018555
# Episode 430/500, Total Reward: 297.34582138061523
# Episode 431/500, Total Reward: 2071.9664039611816
# Episode 432/500, Total Reward: 941.3126220703125
# Episode 433/500, Total Reward: 1015.9313430786133
# Episode 434/500, Total Reward: -1942.5432815551758
# Episode 435/500, Total Reward: -9925.917476654053
# Episode 436/500, Total Reward: 9205.014846801758
# Episode 437/500, Total Reward: -9935.182502746582
# Episode 438/500, Total Reward: 7853.894550323486
# Episode 439/500, Total Reward: -9928.337097167969
# Episode 440/500, Total Reward: -9919.490867614746
# Episode 441/500, Total Reward: -9924.314292907715
# Episode 442/500, Total Reward: -9830.029434204102
# Episode 443/500, Total Reward: -9854.764060974121
# Episode 444/500, Total Reward: -9940.944316864014
# Episode 445/500, Total Reward: -9987.720035552979
# Episode 446/500, Total Reward: -9786.448696136475
# Episode 447/500, Total Reward: -9911.907649993896
# Episode 448/500, Total Reward: -9982.483070373535
# Episode 449/500, Total Reward: -9999.001777648926
# Episode 450/500, Total Reward: -9923.228340148926
# Episode 451/500, Total Reward: -9810.988594055176
# Episode 452/500, Total Reward: -9997.483646392822
# Episode 453/500, Total Reward: -9785.636627197266
# Episode 454/500, Total Reward: -9890.152591705322
# Episode 455/500, Total Reward: -9904.53050994873
# Episode 456/500, Total Reward: -9995.667545318604
# Episode 457/500, Total Reward: -9861.069458007812
# Episode 458/500, Total Reward: -9935.562545776367
# Episode 459/500, Total Reward: -9891.877464294434
# Episode 460/500, Total Reward: -9833.827381134033
# Episode 461/500, Total Reward: -9890.343559265137
# Episode 462/500, Total Reward: -9820.670639038086
# Episode 463/500, Total Reward: -9865.739044189453
# Episode 464/500, Total Reward: -9830.447944641113
# Episode 465/500, Total Reward: -9917.093338012695
# Episode 466/500, Total Reward: -9907.086353302002
# Episode 467/500, Total Reward: -9842.559608459473
# Episode 468/500, Total Reward: -9839.971309661865
# Episode 469/500, Total Reward: 4773.045185089111
# Episode 470/500, Total Reward: -9916.153373718262
# Episode 471/500, Total Reward: -9844.370449066162
# Episode 472/500, Total Reward: -9925.532577514648
# Episode 473/500, Total Reward: -9865.920631408691
# Episode 474/500, Total Reward: -9836.481735229492
# Episode 475/500, Total Reward: -9914.581428527832
# Episode 476/500, Total Reward: -9878.361190795898
# Episode 477/500, Total Reward: -9806.692756652832
# Episode 478/500, Total Reward: 2702.6801986694336
# Episode 479/500, Total Reward: -9932.79613494873
# Episode 480/500, Total Reward: -9995.384780883789
# Episode 481/500, Total Reward: -9845.408996582031
# Episode 482/500, Total Reward: -9844.695728302002
# Episode 483/500, Total Reward: 1919.267406463623
# Episode 484/500, Total Reward: -9857.37247467041
# Episode 485/500, Total Reward: -9846.666389465332
# Episode 486/500, Total Reward: -9803.374755859375
# Episode 487/500, Total Reward: -9867.635612487793
# Episode 488/500, Total Reward: -9861.610824584961
# Episode 489/500, Total Reward: -9868.086242675781
# Episode 490/500, Total Reward: 12082.362815856934
# Episode 491/500, Total Reward: -9842.277717590332
# Episode 492/500, Total Reward: -9936.097518920898
# Episode 493/500, Total Reward: -9913.828510284424
# Episode 494/500, Total Reward: -9924.673904418945
# Episode 495/500, Total Reward: -9896.25938796997
# Episode 496/500, Total Reward: -9819.563949584961
# Episode 497/500, Total Reward: -806.1813278198242
# Episode 498/500, Total Reward: 2277.94002532959
# Episode 499/500, Total Reward: -9862.250671386719
# Episode 500/500, Total Reward: -859.09814453125
# Training Complete!

# %% [markdown]
# Here, we trained the AI Trading Agent using Deep Q-Learning, simulating 500 trading sessions where the agent learned from experience. It leveraged Exploration & Exploitation, initially taking random actions before making more informed decisions as training progressed.
#
#
# Experience Replay is used to store past experiences, allowing the neural network to learn through batch training. Throughout the process, we tracked rewards to measure the agent’s performance improvements over time.
#
# After training, we can test the agent on new market data by allowing it to make decisions without random exploration:

# %%
# create a fresh environment instance for testing
test_env = TradingEnvironment(data)
state = test_env.reset()
done = False

# simulate a trading session using the trained agent
while not done:
    # always choose the best action (exploitation)
    action = agent.act(state)
    next_state, reward, done, _ = test_env.step(action)
    state = next_state if next_state is not None else state

final_balance = test_env.balance
profit = final_balance - test_env.initial_balance
print(f"Final Balance after testing: ${final_balance:.2f}")
print(f"Total Profit: ${profit:.2f}")
# Out:
# /tmp/ipython-input-5-3109401411.py:4: FutureWarning: Calling float on a single element Series is deprecated and will raise a TypeError in the future. Use float(ser.iloc[0]) instead
#   float(data.loc[index, 'Close']),
# /tmp/ipython-input-5-3109401411.py:5: FutureWarning: Calling float on a single element Series is deprecated and will raise a TypeError in the future. Use float(ser.iloc[0]) instead
#   float(data.loc[index, 'SMA_5']),
# /tmp/ipython-input-5-3109401411.py:6: FutureWarning: Calling float on a single element Series is deprecated and will raise a TypeError in the future. Use float(ser.iloc[0]) instead
#   float(data.loc[index, 'SMA_20']),
# /tmp/ipython-input-5-3109401411.py:7: FutureWarning: Calling float on a single element Series is deprecated and will raise a TypeError in the future. Use float(ser.iloc[0]) instead
#   float(data.loc[index, 'Returns'])
# /tmp/ipython-input-6-2218621516.py:17: FutureWarning: Calling float on a single element Series is deprecated and will raise a TypeError in the future. Use float(ser.iloc[0]) instead
#   price = float(self.data.loc[self.index, 'Close'])
# Final Balance after testing: $11355.29
# Total Profit: $1355.29

# %% [markdown]
# **Profit = $1355.29**, meaning the agent made **a positive return.**
#
# So, this is how you can build an AI Agent using Agentic AI.

# %% [markdown]
# ## Summary
# So, in this project, we explored how to build an AI trading agent using Agentic AI and Deep Q-Learning, enabling it to make autonomous trading decisions. After training, our AI agent successfully generated a small but positive profit, which demonstrates its ability to navigate market fluctuations.
